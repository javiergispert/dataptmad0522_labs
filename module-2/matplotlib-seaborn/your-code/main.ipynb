# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x, x, label='linear')
plt.plot(x, y, label='mult')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Linear vs Non Linear Plots")
plt.legend()
plt.show()

# %%
plt.plot(x, x, label='linear')
plt.plot(x, z, label='quadratic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Linear vs Non Linear Plots")
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, axs = plt.subplots(nrows=1, ncols=2)
axs[0].plot(x)
axs[0].plot(y)
axs[1].plot(x)
axs[1].plot(z)
fig.tight_layout()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
axs[0].plot(x)
axs[0].plot(y)
axs[0].set_title("Linear vs Non Linear Plots", fontweight='bold', size=20)
axs[0].set_xlabel('Nº de Elementos', fontsize=15)
axs[0].set_ylabel('Valor', fontsize=15)
axs[1].plot(x)
axs[1].plot(z)
axs[1].set_title("Linear vs Non Linear Plots", fontweight='bold', size=20)
axs[1].set_xlabel('Nº de Elementos', fontsize=15)
axs[1].set_ylabel('Valor', fontsize=15)
fig.tight_layout()
plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
y1 = np.exp(x)
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
axs[0].plot(x)
axs[0].plot(z)
axs[0].set_title("Linear vs Non Linear Plots", fontweight='bold', size=20)
axs[0].set_xlabel('Nº de Elementos', fontsize=15)
axs[0].set_ylabel('Valor', fontsize=15)
axs[0].set_xscale('linear')
axs[1].plot(x)
axs[1].plot(y1)
axs[1].set_title("Linear vs Non Linear Plots", fontweight='bold', size=20)
axs[1].set_xlabel('Nº de Elementos', fontsize=15)
axs[1].set_ylabel('Valor', fontsize=15)
axs[1].set_yscale('log')
axs[1].set_xscale('log')
fig.tight_layout()
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
axs[0].plot(x, label='linear')
axs[0].plot(z, label='squared')
axs[0].legend(loc="upper left")
axs[0].set_title("Linear vs Non Linear Plots", fontweight='bold', size=20)
axs[0].set_xlabel('Nº de Elementos', fontsize=15)
axs[0].set_ylabel('Valor', fontsize=15)
axs[0].set_xscale('linear')
axs[1].plot(x, label='linear')
axs[1].plot(y1, label='e number')
axs[1].legend(loc="upper left")
axs[1].set_title("Linear vs Non Linear Plots", fontweight='bold', size=20)
axs[1].set_xlabel('Nº de Elementos', fontsize=15)
axs[1].set_ylabel('Valor', fontsize=15)
axs[1].set_yscale('log')
axs[1].set_xscale('log')
fig.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('../data/fitbit2.csv')
fitbit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        367 non-null    object
#  1   Calorie burned              367 non-null    int64
#  2   Steps                       367 non-null    int64
#  3   Distance                    367 non-null    float64
#  4   Floors                      367 non-null    int64
#  5   Minutes Sedentary           367 non-null    float64
#  6   Minutes Lightly Active      367 non-null    int64
#  7   Minutes Fairly Active       367 non-null    int64
#  8   Minutes Very Active         367 non-null    int64
#  9   Activity Calories           367 non-null    int64
#  10  MinutesOfSleep              367 non-null    int64
#  11  MinutesOfBeingAwake         367 non-null    int64
#  12  NumberOfAwakings            367 non-null    int64
# ...

# %%
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
steps = fitbit.groupby(['Months']).mean()
steps_mean = steps['Months_encoded']
steps_work = steps['Work_or_Weekend']
#steps_mean
steps.head()
# Out:
#           Calorie burned         Steps   Distance     Floors  \
# Months
# April        3030.800000  13079.033333  11.190667  11.566667
# August       2844.967742  11584.774194   9.059677  14.129032
# December     2737.290323   8470.064516   7.460323   8.935484
# February     2600.100000   8922.866667   7.143667   9.666667
# January      2812.806452   9892.064516   7.912581   8.580645
#
#           Minutes Sedentary  Minutes Lightly Active  Minutes Fairly Active  \
# Months
# April            638.469700              293.866667              13.800000
# August           497.499000              265.322581              25.903226
# December         525.882935              236.032258              19.870968
# February         598.077133              214.933333              25.166667
# January          573.702000              249.838710              27.548387
#
#           Minutes Very Active  Activity Calories  MinutesOfSleep  ...  \
# ...

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
axs[0].plot(steps_mean, label='median Steps by Month')
axs[0].legend(loc="upper left")
axs[0].set_title("Análisis Pasos al mes", fontweight='bold', size=20)
axs[0].set_xlabel('Meses', fontsize=15)
axs[0].set_ylabel('Month_Encoded', fontsize=15)
#axs[0].set_xscale('linear')
plt.sca(axs[0])
#plt.plot(x, y1)
plt.xticks(x, rotation='vertical')
# Pad margins so that markers don't get clipped by the axes
plt.margins(0.1)
# Tweak spacing to prevent clipping of tick-labels
plt.subplots_adjust(bottom=0.15)

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
axs[1].plot(steps_work, label='median Steps by Work_or_Weekend')
axs[1].legend(loc="upper left")
axs[1].set_title("Análisis Pasos al mes", fontweight='bold', size=20)
axs[1].set_xlabel('Meses', fontsize=15)
axs[1].set_ylabel('Media de Work-Weekend', fontsize=15)
plt.sca(axs[1])
#plt.plot(x, y1)
plt.xticks(x, rotation='vertical')
# Pad margins so that markers don't get clipped by the axes
plt.margins(0.1)
# Tweak spacing to prevent clipping of tick-labels
plt.subplots_adjust(bottom=0.15)

fig.tight_layout()
#plt.legend()
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
steps_active = steps[['Steps', 'Minutes Sedentary', 'Minutes Lightly Active', 'Minutes Very Active']]
steps_active.head()
# Out:
#                  Steps  Minutes Sedentary  Minutes Lightly Active  \
# Months
# April     13079.033333         638.469700              293.866667
# August    11584.774194         497.499000              265.322581
# December   8470.064516         525.882935              236.032258
# February   8922.866667         598.077133              214.933333
# January    9892.064516         573.702000              249.838710
#
#           Minutes Very Active
# Months
# April               48.866667
# August              28.516129
# December            29.645161
# February            25.033333
# January             27.387097

# %%
# your code here
for i in steps_active.columns:
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(steps_active['Steps'], label='Steps', color='red')
    ax2 = ax.twinx()
    ax2.plot(steps_active[i])
    plt.title('Steps vs')
    # plt.legend()
    # Show/save figure as desired.
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

# %%
# CATEGORICAL VARIABLES
# your code here

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
